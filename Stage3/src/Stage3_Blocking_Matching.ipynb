# %% [markdown]
# # Complete WorkFlow for Entity Matching

# %% [markdown]
# This jupyter notebook loads two tables with around 3000 tuples. Each tuple describe a movie. Goal is to find matching tuples between the two tables.

# %%
# Import py_entitymatching package and other required packages
import py_entitymatching as em
import os
import pandas as pd
import math

pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',1000)

# %%
# Get the datasets directory
datasets_dir = 'CleanData'

# Get the paths of the input tables
path_A = datasets_dir + os.sep + 'Table_IMDB_with_ID.csv'
path_B = datasets_dir + os.sep + 'Table_Allmovie_with_ID.csv'

# %%
# Read the CSV files and set 'MID' as the key attribute
A = em.read_csv_metadata(path_A, key='MID')
B = em.read_csv_metadata(path_B, key='MID')
# Out:
# No handlers could be found for logger "py_entitymatching.io.parsers"

# %%
DEBUG = False

# %% [markdown]
# ## First step in the entity matching process is blocking. We apply some rules to perform blocking, while ensuring that positive tuples do not get blocked.
#
#
# We have used to blocking rules sequentially to perform blocking.
#
# Rule 1: 3 gram Jaccard measure on movie titles
#
# Rule 2: 2 gram Overlapping measure on directors' names

# %% [markdown]
# ### Applying Blocking Rule 1

# %%
#rule based blocking
block_f = em.get_features_for_blocking(A, B, validate_inferred_attr_types=False)

# %%
rb = em.RuleBasedBlocker()
# Add rule : block tuples with given rule: 
rb.add_rule(['Title_Title_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.3'], block_f)
# Out:
# '_rule_0'

# %%
#applying the fir
D1 = rb.block_tables(A, B, 
                    l_output_attrs=['Title', 'Certificate', 'Genre','Rating','Running Time', 'Directors','Stars Cast','Country','Release Date','Production Company','Release Year','Release Month'],
                    r_output_attrs=['Title', 'Certificate', 'Genre','Rating','Running Time', 'Directors','Stars Cast','Country','Release Date','Production Company','Release Year','Release Month'],
                
                     l_output_prefix='l_', r_output_prefix='r_',
                    )
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# Finding pairs with missing value...

# %%
len(D1)
# Out:
# 5210

# %%
D1.head()
# Out:
#    _id l_MID r_MID               l_Title l_Certificate  \
# 0    0     2     1                     9          PG13
# 1    1     3     2                    10             R
# 2    2    20     2                 10x10           NaN
# 3    3     7     3                  1408          PG13
# 4    4    12     6  (500) Days of Summer          PG13
#
#                       l_Genre  l_Rating l_Running Time    l_Directors  \
# 0  Animation|Action|Adventure       7.1         79 min    Shane Acker
# 1              Comedy|Romance       6.0        122 min  Blake Edwards
# 2                    Thriller       5.3         88 min     Suzi Ewing
# 3                Drama|Horror       6.8        104 min  Mikael Hfstrm
# 4        Comedy|Drama|Romance       7.7         95 min      Marc Webb
#
#                                           l_Stars Cast l_Country  \
# 0         Elijah Wood|Jennifer Connelly|Crispin Glover       USA
# 1                  Dudley Moore|Bo Derek|Julie Andrews       USA
# 2                  Luke Evans|Kelly Reilly|Noel Clarke        UK
# 3         John Cusack|Samuel L. Jackson|Mary McCormack       USA
# 4  Zooey Deschanel|Joseph Gordon-Levitt|Geoffrey Arend       USA
#
#   l_Release Date  \
# 0       9-Sep-09
# 1       5-Oct-79
# 2      13-Apr-18
# 3      22-Jun-07
# 4       7-Aug-09
#
#                                             l_Production Company  \
# 0                Focus Features|Relativity Media|Arc Productions
# 1                            Geoffrey Productions|Orion Pictures
# 2    Unstoppable Entertainment|Head Gear Films|Metrol Technology
# 3  Dimension Films|The Weinstein Company|Di Bonaventura Pictures
# 4      Fox Searchlight Pictures|Watermark|Dune Entertainment III
#
#    l_Release Year l_Release Month               r_Title r_Certificate  \
# 0          2009.0       September                     9          PG13
# 1          1979.0         October                    10             R
# 2          2018.0           April                    10             R
# 3          2007.0            June                  1408          PG13
# 4          2009.0          August  (500) Days of Summer          PG13
#
#                   r_Genre r_Rating r_Running Time    r_Directors  \
# 0  Action|Science Fiction        8         79 min    Shane Acker
# 1                  Comedy        8        121 min  Blake Edwards
# 2                  Comedy        8        121 min  Blake Edwards
# 3                  Horror        7         94 min  Mikael Hfstrm
# 4                  Comedy        8         95 min      Marc Webb
#
#                                                            r_Stars Cast  \
# 0       Christopher Plummer|Martin Landau|John C. Reilly|Crispin Glover
# 1                     Dudley Moore|Julie Andrews|Bo Derek|Robert Webber
# 2                     Dudley Moore|Julie Andrews|Bo Derek|Robert Webber
# 3  John Cusack|Samuel L. Jackson|Mary McCormack|Jasmine Jessica Anthony
# 4          Zooey Deschanel|Joseph Gordon-Levitt|Clark Gregg|Minka Kelly
#
#   r_Country r_Release Date  \
# 0       USA       9-Sep-09
# 1       USA       5-Oct-79
# 2       USA       5-Oct-79
# 3       USA      22-Jun-07
# 4       USA      17-Jul-09
#
#                                            r_Production Company  \
# 0                                                Focus Features
# 1                                         Orion|Warner Brothers
# 2                                         Orion|Warner Brothers
# 3  Dimension Films|Lorenzo di Bonaventura|Senator Entertainment
# 4                                         Watermark Productions
#
#    r_Release Year r_Release Month
# 0          2009.0       September
# 1          1979.0         October
# 2          1979.0         October
# 3          2007.0            June
# 4          2009.0            July

# %%
if DEBUG:
    dbg = em.debug_blocker(D1, A, B, output_size=100)
    dbg.to_csv(datasets_dir + os.sep +'D1_block_dbg.csv')

# %% [markdown]
# ### Applying Blocking Rule 2

# %%
# Instantiate overlap blocker object
ob = em.OverlapBlocker()

# %%
# for debugging only
if DEBUG:
    # Specify the tokenization to be 'word' level and set overlap_size to be 3.
    D2 = ob.block_tables(A, B, 'Directors', 'Directors', word_level=False, q_val=2, overlap_size=2,
                     l_output_attrs=['Title', 'Certificate', 'Genre','Rating','Running Time', 'Directors','Stars Cast','Country','Release Date','Production Company','Release Year','Release Month'],
                     r_output_attrs=['Title', 'Certificate', 'Genre','Rating','Running Time', 'Directors','Stars Cast','Country','Release Date','Production Company','Release Year','Release Month'],
                        show_progress=False)

else:
    D2 = ob.block_candset(D1,'Directors', 'Directors',word_level=False, q_val=2, overlap_size=2, show_progress=False)

# %%
len(D2)
# Out:
# 2028

# %%
D2.head()
# Out:
#    _id l_MID r_MID               l_Title l_Certificate  \
# 0    0     2     1                     9          PG13
# 1    1     3     2                    10             R
# 3    3     7     3                  1408          PG13
# 4    4    12     6  (500) Days of Summer          PG13
# 6    6    16    12   10 Cloverfield Lane          PG13
#
#                       l_Genre  l_Rating l_Running Time       l_Directors  \
# 0  Animation|Action|Adventure       7.1         79 min       Shane Acker
# 1              Comedy|Romance       6.0        122 min     Blake Edwards
# 3                Drama|Horror       6.8        104 min     Mikael Hfstrm
# 4        Comedy|Drama|Romance       7.7         95 min         Marc Webb
# 6        Drama|Horror|Mystery       7.2        103 min  Dan Trachtenberg
#
#                                               l_Stars Cast l_Country  \
# 0             Elijah Wood|Jennifer Connelly|Crispin Glover       USA
# 1                      Dudley Moore|Bo Derek|Julie Andrews       USA
# 3             John Cusack|Samuel L. Jackson|Mary McCormack       USA
# 4      Zooey Deschanel|Joseph Gordon-Levitt|Geoffrey Arend       USA
# 6  John Goodman|Mary Elizabeth Winstead|John Gallagher Jr.       USA
#
#   l_Release Date  \
# 0       9-Sep-09
# 1       5-Oct-79
# 3      22-Jun-07
# 4       7-Aug-09
# 6      11-Mar-16
#
#                                             l_Production Company  \
# 0                Focus Features|Relativity Media|Arc Productions
# 1                            Geoffrey Productions|Orion Pictures
# 3  Dimension Films|The Weinstein Company|Di Bonaventura Pictures
# 4      Fox Searchlight Pictures|Watermark|Dune Entertainment III
# 6                  Paramount Pictures|Bad Robot|Spectrum Effects
#
#    l_Release Year l_Release Month               r_Title r_Certificate  \
# 0          2009.0       September                     9          PG13
# 1          1979.0         October                    10             R
# 3          2007.0            June                  1408          PG13
# 4          2009.0          August  (500) Days of Summer          PG13
# 6          2016.0           March   10 Cloverfield Lane          PG13
#
#                     r_Genre r_Rating r_Running Time       r_Directors  \
# 0    Action|Science Fiction        8         79 min       Shane Acker
# 1                    Comedy        8        121 min     Blake Edwards
# 3                    Horror        7         94 min     Mikael Hfstrm
# 4                    Comedy        8         95 min         Marc Webb
# 6  Science Fiction|Thriller        8        103 min  Dan Trachtenberg
#
#                                                             r_Stars Cast  \
# 0        Christopher Plummer|Martin Landau|John C. Reilly|Crispin Glover
# 1                      Dudley Moore|Julie Andrews|Bo Derek|Robert Webber
# 3   John Cusack|Samuel L. Jackson|Mary McCormack|Jasmine Jessica Anthony
# 4           Zooey Deschanel|Joseph Gordon-Levitt|Clark Gregg|Minka Kelly
# 6  Mary Elizabeth Winstead|John Goodman|John Gallagher, Jr.|Maya Erskine
#
#   r_Country r_Release Date  \
# 0       USA       9-Sep-09
# 1       USA       5-Oct-79
# 3       USA      22-Jun-07
# 4       USA      17-Jul-09
# 6       USA      11-Mar-16
#
#                                            r_Production Company  \
# 0                                                Focus Features
# 1                                         Orion|Warner Brothers
# 3  Dimension Films|Lorenzo di Bonaventura|Senator Entertainment
# 4                                         Watermark Productions
# 6                                                     Bad Robot
#
#    r_Release Year r_Release Month
# 0          2009.0       September
# 1          1979.0         October
# 3          2007.0            June
# 4          2009.0            July
# 6          2016.0           March

# %%
if DEBUG:
    dbg = em.debug_blocker(D2, A, B, output_size=1000,n_jobs=4)
    dbg.to_csv(datasets_dir + os.sep +'D2_block_dbg.csv')

# %%
#saving the final output after blocking to do further process
D2.to_csv(datasets_dir + os.sep +'Blocked_output.csv')

# %% [markdown]
# ## After we got the potential tuples after blocking step, we sampled 500 tuples, which were then labelled and then divided into I and J set for development and testing respectively.

# %%
#loading the output of blocking step
path_C = datasets_dir + os.sep + 'Blocked_output.csv'
C = em.read_csv_metadata(path_C, key='_id', 
                         fk_ltable='l_MID', fk_rtable='r_MID',
                         ltable=A, rtable=B)

# %%
len(C)
# Out:
# 2028

# %%
#fixing a seed for reproducibility and sampling
pd.np.random.seed(100)
S = em.sample_table(C, 500)

# %%
# Label the sampled set
# Specify the name for the label column
G = em.label_table(S, 'gold_label')
# Out:
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/py_entitymatching/gui/table_gui.py:94: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   table.set_value(idxv[i], cols[j], val)

# %%
#writing G to a file for manual labelling
G.to_csv(datasets_dir + os.sep+'Labelled_data.csv')

# %% [markdown]
# ## We now manually label all 500 samples and rename the file to avoid overwriting on labelled files.

# %%
# load the labelled data
path_C = datasets_dir + os.sep + 'Labelled_data_final.csv'
G = em.read_csv_metadata(path_C, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='l_MID', fk_rtable='r_MID')
len(G)
# Out:
# 500

# %% [markdown]
# ### 500 samples are now divided into set I and set J (70 and 30 % respectively). Set I is used to decide the best matcher using cross validation and set J is used to find the accuracy of best matcher once the matcher has been decided and fixed.

# %%
# Split S into I an J
IJ = em.split_train_test(G, train_proportion=0.7, random_state=500)
I = IJ['train']
J = IJ['test']

# %%
#writing I and J to files.
I.to_csv(datasets_dir + os.sep+'I_data.csv')
J.to_csv(datasets_dir + os.sep+'J_data.csv')

# %%
atypes1 = em.get_attr_types(A)
atypes2 = em.get_attr_types(B)

# %%
block_c = em.get_attr_corres(A, B)

# %%
block_c['corres']
# Out:
# [('MID', 'MID'),
#  ('Title', 'Title'),
#  ('Certificate', 'Certificate'),
#  ('Genre', 'Genre'),
#  ('Rating', 'Rating'),
#  ('Running Time', 'Running Time'),
#  ('Directors', 'Directors'),
#  ('Stars Cast', 'Stars Cast'),
#  ('Country', 'Country'),
#  ('Release Date', 'Release Date'),
#  ('Production Company', 'Production Company'),
#  ('Release Year', 'Release Year'),
#  ('Release Month', 'Release Month')]

# %%
# selecting the attributes which we want to use to extract features

block_c['corres'] = [
 ('Title', 'Title'),
 ('Running Time', 'Running Time'),
 ('Directors', 'Directors'),
 ('Stars Cast', 'Stars Cast'),
 ('Release Year', 'Release Year'),
 ('Genre', 'Genre')]

# %%
# for matching 
tok = em.get_tokenizers_for_matching()

# %%
#for matching
sim = em.get_sim_funs_for_matching()

# %%
sim
# Out:
# {'abs_norm': <function py_entitymatching.feature.simfunctions.abs_norm>,
#  'affine': <function py_entitymatching.feature.simfunctions.affine>,
#  'cosine': <function py_entitymatching.feature.simfunctions.cosine>,
#  'dice': <function py_entitymatching.feature.simfunctions.dice>,
#  'exact_match': <function py_entitymatching.feature.simfunctions.exact_match>,
#  'hamming_dist': <function py_entitymatching.feature.simfunctions.hamming_dist>,
#  'hamming_sim': <function py_entitymatching.feature.simfunctions.hamming_sim>,
#  'jaccard': <function py_entitymatching.feature.simfunctions.jaccard>,
#  'jaro': <function py_entitymatching.feature.simfunctions.jaro>,
#  'jaro_winkler': <function py_entitymatching.feature.simfunctions.jaro_winkler>,
#  'lev_dist': <function py_entitymatching.feature.simfunctions.lev_dist>,
#  'lev_sim': <function py_entitymatching.feature.simfunctions.lev_sim>,
#  'monge_elkan': <function py_entitymatching.feature.simfunctions.monge_elkan>,
#  'needleman_wunsch': <function py_entitymatching.feature.simfunctions.needleman_wunsch>,
#  'overlap_coeff': <function py_entitymatching.feature.simfunctions.overlap_coeff>,
#  'rel_diff': <function py_entitymatching.feature.simfunctions.rel_diff>,
#  'smith_waterman': <function py_entitymatching.feature.simfunctions.smith_waterman>}

# %%
# get all features based on selected attributes
F = em.get_features(A, B, atypes1, atypes2, block_c, tok, sim)

# %%
F
# Out:
#                                      feature_name left_attribute  \
# 0                     Title_Title_jac_qgm_3_qgm_3          Title
# 1                 Title_Title_cos_dlm_dc0_dlm_dc0          Title
# 2                 Title_Title_jac_dlm_dc0_dlm_dc0          Title
# 3                                 Title_Title_mel          Title
# 4                            Title_Title_lev_dist          Title
# 5                             Title_Title_lev_sim          Title
# 6                                 Title_Title_nmw          Title
# 7                                  Title_Title_sw          Title
# 8       Running_Time_Running_Time_jac_qgm_3_qgm_3   Running Time
# 9   Running_Time_Running_Time_cos_dlm_dc0_dlm_dc0   Running Time
# 10  Running_Time_Running_Time_jac_dlm_dc0_dlm_dc0   Running Time
# 11                  Running_Time_Running_Time_mel   Running Time
# 12             Running_Time_Running_Time_lev_dist   Running Time
# 13              Running_Time_Running_Time_lev_sim   Running Time
# 14                  Running_Time_Running_Time_nmw   Running Time
# 15                   Running_Time_Running_Time_sw   Running Time
# 16            Directors_Directors_jac_qgm_3_qgm_3      Directors
# 17        Directors_Directors_cos_dlm_dc0_dlm_dc0      Directors
# 18        Directors_Directors_jac_dlm_dc0_dlm_dc0      Directors
# 19                        Directors_Directors_mel      Directors
# 20                   Directors_Directors_lev_dist      Directors
# 21                    Directors_Directors_lev_sim      Directors
# 22                        Directors_Directors_nmw      Directors
# 23                         Directors_Directors_sw      Directors
# 24                  Release_Year_Release_Year_exm   Release Year
# 25                  Release_Year_Release_Year_anm   Release Year
# 26             Release_Year_Release_Year_lev_dist   Release Year
# 27              Release_Year_Release_Year_lev_sim   Release Year
#
#    right_attribute left_attr_tokenizer right_attr_tokenizer       simfunction  \
# 0            Title               qgm_3                qgm_3           jaccard
# 1            Title             dlm_dc0              dlm_dc0            cosine
# 2            Title             dlm_dc0              dlm_dc0           jaccard
# 3            Title                None                 None       monge_elkan
# 4            Title                None                 None          lev_dist
# 5            Title                None                 None           lev_sim
# 6            Title                None                 None  needleman_wunsch
# 7            Title                None                 None    smith_waterman
# 8     Running Time               qgm_3                qgm_3           jaccard
# 9     Running Time             dlm_dc0              dlm_dc0            cosine
# 10    Running Time             dlm_dc0              dlm_dc0           jaccard
# 11    Running Time                None                 None       monge_elkan
# 12    Running Time                None                 None          lev_dist
# 13    Running Time                None                 None           lev_sim
# 14    Running Time                None                 None  needleman_wunsch
# 15    Running Time                None                 None    smith_waterman
# 16       Directors               qgm_3                qgm_3           jaccard
# 17       Directors             dlm_dc0              dlm_dc0            cosine
# 18       Directors             dlm_dc0              dlm_dc0           jaccard
# 19       Directors                None                 None       monge_elkan
# 20       Directors                None                 None          lev_dist
# 21       Directors                None                 None           lev_sim
# 22       Directors                None                 None  needleman_wunsch
# 23       Directors                None                 None    smith_waterman
# 24    Release Year                None                 None       exact_match
# 25    Release Year                None                 None          abs_norm
# 26    Release Year                None                 None          lev_dist
# 27    Release Year                None                 None           lev_sim
#
#                                                                    function  \
# 0                     <function Title_Title_jac_qgm_3_qgm_3 at 0x116073aa0>
# 1                 <function Title_Title_cos_dlm_dc0_dlm_dc0 at 0x116073578>
# 2                 <function Title_Title_jac_dlm_dc0_dlm_dc0 at 0x116073140>
# 3                                 <function Title_Title_mel at 0x116073b18>
# 4                            <function Title_Title_lev_dist at 0x116073c80>
# 5                             <function Title_Title_lev_sim at 0x116073488>
# 6                                 <function Title_Title_nmw at 0x116073f50>
# 7                                  <function Title_Title_sw at 0x116073668>
# 8       <function Running_Time_Running_Time_jac_qgm_3_qgm_3 at 0x1160739b0>
# 9   <function Running_Time_Running_Time_cos_dlm_dc0_dlm_dc0 at 0x1160738c0>
# 10  <function Running_Time_Running_Time_jac_dlm_dc0_dlm_dc0 at 0x116073410>
# 11                  <function Running_Time_Running_Time_mel at 0x116073320>
# 12             <function Running_Time_Running_Time_lev_dist at 0x115d5a758>
# 13              <function Running_Time_Running_Time_lev_sim at 0x115d5a848>
# 14                  <function Running_Time_Running_Time_nmw at 0x115d5a7d0>
# 15                   <function Running_Time_Running_Time_sw at 0x115d5a500>
# 16            <function Directors_Directors_jac_qgm_3_qgm_3 at 0x115d5a488>
# 17        <function Directors_Directors_cos_dlm_dc0_dlm_dc0 at 0x11b157668>
# 18        <function Directors_Directors_jac_dlm_dc0_dlm_dc0 at 0x11b1576e0>
# 19                        <function Directors_Directors_mel at 0x11b157c08>
# 20                   <function Directors_Directors_lev_dist at 0x11b157a28>
# 21                    <function Directors_Directors_lev_sim at 0x11b157b90>
# 22                        <function Directors_Directors_nmw at 0x11b157758>
# 23                         <function Directors_Directors_sw at 0x11b157c80>
# 24                  <function Release_Year_Release_Year_exm at 0x11b157578>
# 25                  <function Release_Year_Release_Year_anm at 0x11b1575f0>
# 26             <function Release_Year_Release_Year_lev_dist at 0x11b157b18>
# 27              <function Release_Year_Release_Year_lev_sim at 0x11b1579b0>
#
#                                                                                         function_source  \
# 0   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 1   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 2   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 3   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 4   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 5   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 6   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 7   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 8   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 9   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 10  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 11  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 12  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 13  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 14  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 15  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 16  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 17  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 18  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 19  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 20  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 21  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 22  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 23  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 24  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 25  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 26  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 27  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
#
#     is_auto_generated
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True
# 10               True
# 11               True
# 12               True
# 13               True
# 14               True
# 15               True
# 16               True
# 17               True
# 18               True
# 19               True
# 20               True
# 21               True
# 22               True
# 23               True
# 24               True
# 25               True
# 26               True
# 27               True

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
lr = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NaiveBayes')

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='gold_label',
                            show_progress=False)

# %%
H.head()
# Out:
#       _id  l_MID  r_MID  Title_Title_jac_qgm_3_qgm_3  \
# 186  1604   1738   1856                     0.384615
# 418  4304   2529   2812                     0.476190
# 472  4159   2650   2779                     0.300000
# 182  1577   1710   1836                     1.000000
# 268  2285   2154   2316                     0.333333
#
#      Title_Title_cos_dlm_dc0_dlm_dc0  Title_Title_jac_dlm_dc0_dlm_dc0  \
# 186                         0.666667                         0.500000
# 418                         0.666667                         0.500000
# 472                         0.500000                         0.333333
# 182                         1.000000                         1.000000
# 268                         0.500000                         0.333333
#
#      Title_Title_mel  Title_Title_lev_dist  Title_Title_lev_sim  \
# 186         0.893961                   9.0             0.653846
# 418         0.926374                   4.0             0.714286
# 472         0.828095                   6.0             0.500000
# 182         1.000000                   0.0             1.000000
# 268         0.853968                   4.0             0.555556
#
#      Title_Title_nmw  Title_Title_sw  \
# 186             15.0            16.0
# 418              9.0            10.0
# 472              4.0             4.0
# 182             11.0            11.0
# 268              3.0             5.0
#
#      Running_Time_Running_Time_jac_qgm_3_qgm_3  \
# 186                                   0.454545
# 418                                   0.307692
# 472                                   0.384615
# 182                                   0.500000
# 268                                   0.307692
#
#      Running_Time_Running_Time_cos_dlm_dc0_dlm_dc0  \
# 186                                            0.5
# 418                                            0.5
# 472                                            0.5
# 182                                            0.5
# 268                                            0.5
#
#      Running_Time_Running_Time_jac_dlm_dc0_dlm_dc0  \
# 186                                       0.333333
# 418                                       0.333333
# 472                                       0.333333
# 182                                       0.333333
# 268                                       0.333333
#
#      Running_Time_Running_Time_mel     ...      Running_Time_Running_Time_nmw  \
# 186                       0.900000     ...                                5.0
# 418                       0.849206     ...                                3.0
# 472                       0.828571     ...                                5.0
# 182                       0.923810     ...                                6.0
# 268                       0.746032     ...                                3.0
#
#      Running_Time_Running_Time_sw  Directors_Directors_jac_qgm_3_qgm_3  \
# 186                           5.0                             1.000000
# 418                           4.0                             0.277778
# 472                           5.0                             0.000000
# 182                           6.0                             1.000000
# 268                           4.0                             0.000000
#
#      Directors_Directors_cos_dlm_dc0_dlm_dc0  \
# 186                                      1.0
# 418                                      0.5
# 472                                      0.0
# 182                                      1.0
# 268                                      0.0
#
#      Directors_Directors_jac_dlm_dc0_dlm_dc0  Directors_Directors_mel  \
# 186                                 1.000000                 1.000000
# 418                                 0.333333                 0.853333
# 472                                 0.000000                 0.432372
# 182                                 1.000000                 1.000000
# 268                                 0.000000                 0.513558
#
#      Directors_Directors_lev_dist  Directors_Directors_lev_sim  \
# 186                           0.0                     1.000000
# 418                           4.0                     0.600000
# 472                          14.0                     0.125000
# 182                           0.0                     1.000000
# 268                          16.0                     0.111111
#
#      Directors_Directors_nmw  Directors_Directors_sw  \
# 186                     18.0                    18.0
# 418                      5.0                     6.0
# 472                     -1.0                     2.0
# 182                     15.0                    15.0
# 268                      0.0                     2.0
#
#      Release_Year_Release_Year_exm  Release_Year_Release_Year_anm  \
# 186                            0.0                       0.999006
# 418                            NaN                            NaN
# 472                            0.0                       0.991538
# 182                            1.0                       1.000000
# 268                            0.0                       0.992560
#
#      Release_Year_Release_Year_lev_dist  Release_Year_Release_Year_lev_sim  \
# 186                                 1.0                           0.833333
# 418                                 NaN                                NaN
# 472                                 4.0                           0.333333
# 182                                 0.0                           1.000000
# 268                                 2.0                           0.666667
#
#      gold_label
# 186           0
# 418           0
# 472           0
# 182           1
# 268           0
#
# [5 rows x 32 columns]

# %%
# Check if the feature vectors contain missing values
# A return value of True means that there are missing values
any(pd.notnull(H))
# Out:
# True

# %%
# Impute feature vectors with the mean of the column values.
H = em.impute_table(H, 
                exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
                strategy='mean')

# %%
# Select the best ML matcher using CV
result = em.select_matcher([dt, rf, svm, lg, lr, nb], table=H, 
        exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
        k=5,
        target_attr='gold_label', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']
# Out:
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.979144        0.961538    0.968012
# 1            RF           0.990909        0.961538    0.974072
# 2           SVM           0.962609        0.871179    0.911405
# 3        LogReg           0.960386        0.961538    0.957868
# 4        LinReg           0.956727        0.976923    0.966217
# 5    NaiveBayes           0.982576        0.961538    0.969817

# %%
# result['drill_down_cv_stats']['precision']

# %%
# result['drill_down_cv_stats']['recall']

# %%
# result['drill_down_cv_stats']['f1']

# %%
# this part of the code was used to debug the selected matcher
# # Split H into P and Q
# PQ = em.split_train_test(H, train_proportion=0.5, random_state=0)
# P = PQ['train']
# Q = PQ['test']

# %%
# # Debug RF matcher using GUI
# em.vis_debug_rf(rf, P, Q, 
#         exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
#         target_attr='gold_label')

# %% [markdown]
# ## Once the matcher was selected based on the cross validation accuracy, we now use the selected matcher to train the model on I set and test it on J set.

# %%
# Train using feature vectors from I 
rf.fit(table=H, 
        exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
       target_attr='gold_label')

# Convert J into a set of feature vectors using F
L = em.extract_feature_vecs(J, feature_table=F,
                            attrs_after='gold_label', show_progress=False)

# Impute feature vectors with the mean of the column values.
L = em.impute_table(L, 
                exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
                strategy='mean')


# Predict on L 
predictions = rf.predict(table=L, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
              append=True, target_attr='predicted', inplace=False, return_probs=True,
                        probs_attr='proba')

# %%
# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'gold_label', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 97.67% (42/43)
# Recall : 95.45% (42/44)
# F1 : 96.55%
# False positives : 1 (out of 43 positive predictions)
# False negatives : 2 (out of 107 negative predictions)

# %%
# testing set J on all remaining matchers:

# Train using feature vectors from I 
dt.fit(table=H, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
       target_attr='gold_label')

svm.fit(table=H, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
       target_attr='gold_label')

lg.fit(table=H, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
       target_attr='gold_label')

lr.fit(table=H, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
       target_attr='gold_label')

nb.fit(table=H, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
       target_attr='gold_label')

# Convert J into a set of feature vectors using F
L = em.extract_feature_vecs(J, feature_table=F,
                            attrs_after='gold_label', show_progress=False)
# Impute feature vectors with the mean of the column values.
L = em.impute_table(L, 
                exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
                strategy='mean')


# Predict on L 
predictionsDT = dt.predict(table=L, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
              append=True, target_attr='predicted', inplace=False, return_probs=True,
                        probs_attr='proba')

predictionsSVM = svm.predict(table=L, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
              append=True, target_attr='predicted', inplace=False)

predictionsLG = lg.predict(table=L, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
              append=True, target_attr='predicted', inplace=False, return_probs=True,
                        probs_attr='proba')
predictionsLR = lr.predict(table=L, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
              append=True, target_attr='predicted', inplace=False, return_probs=True,
                        probs_attr='proba')
predictionsNB = nb.predict(table=L, exclude_attrs=['_id', 'l_MID', 'r_MID', 'gold_label'],
              append=True, target_attr='predicted', inplace=False, return_probs=True,
                        probs_attr='proba')
# Out:
# /Users/sonuagarwal/anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
# Evaluate the predictions
eval_result = em.eval_matches(predictionsDT, 'gold_label', 'predicted')
em.print_eval_summary(eval_result)

# Evaluate the predictions
eval_result = em.eval_matches(predictionsSVM, 'gold_label', 'predicted')
em.print_eval_summary(eval_result)

# Evaluate the predictions
eval_result = em.eval_matches(predictionsLG, 'gold_label', 'predicted')
em.print_eval_summary(eval_result)

# Evaluate the predictions
eval_result = em.eval_matches(predictionsLR, 'gold_label', 'predicted')
em.print_eval_summary(eval_result)

# Evaluate the predictions
eval_result = em.eval_matches(predictionsNB, 'gold_label', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 91.3% (42/46)
# Recall : 95.45% (42/44)
# F1 : 93.33%
# False positives : 4 (out of 46 positive predictions)
# False negatives : 2 (out of 104 negative predictions)
# Precision : 90.7% (39/43)
# Recall : 88.64% (39/44)
# F1 : 89.66%
# False positives : 4 (out of 43 positive predictions)
# False negatives : 5 (out of 107 negative predictions)
# Precision : 91.67% (44/48)
# Recall : 100.0% (44/44)
# F1 : 95.65%
# False positives : 4 (out of 48 positive predictions)
# False negatives : 0 (out of 102 negative predictions)
# Precision : 93.62% (44/47)
# Recall : 100.0% (44/44)
# F1 : 96.7%
# False positives : 3 (out of 47 positive predictions)
# False negatives : 0 (out of 103 negative predictions)
# Precision : 89.36% (42/47)
# Recall : 95.45% (42/44)
# F1 : 92.31%
# False positives : 5 (out of 47 positive predictions)
# False negatives : 2 (out of 103 negative predictions)
